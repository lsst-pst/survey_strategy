# %% [markdown]
# # Deep Drilling Field observing strategy

# %%
# Import required python modules
import os
import numpy as np
import matplotlib.pyplot as plt
import healpy as hp
import pandas as pd
import sqlite3
from astropy.coordinates import SkyCoord
import astropy.units as u
import rubin_scheduler.scheduler.utils as sched_utils
from rubin_scheduler.utils import ddf_locations
from rubin_sim.data import get_baseline
import rubin_sim.maf as maf

# %%
# v5.0.0 runs
summaries = maf.get_metric_summaries(summary_source='summary.h5')
print(f"This summary h5 file contains information on {len(summaries.index)} simulations.")
print(summaries.index)
# Out:
# This summary h5 file contains information on 46 simulations.
# Index(['baseline_v2.0_10yrs', 'baseline_v2.1_10yrs', 'baseline_v2.2_10yrs',
#        'baseline_v3.0_10yrs', 'baseline_v3.2_10yrs', 'baseline_v3.3_10yrs',
#        'baseline_v3.4_10yrs', 'baseline_v3.5_10yrs', 'baseline_v3.6_10yrs',
#        'baseline_v4.0_10yrs', 'baseline_v4.1_10yrs', 'baseline_v4.2_10yrs',
#        'baseline_v4.3.5_10yrs', 'baseline_v5.0.0_10yrs',
#        'ddf_accourdion_v5.0.0_10yrs', 'ddf_dither_0.0_v5.0.0_10yrs',
#        'ddf_dither_0.1_v5.0.0_10yrs', 'ddf_dither_0.2_v5.0.0_10yrs',
#        'ddf_dither_0.4_v5.0.0_10yrs', 'ddf_dither_0.8_v5.0.0_10yrs',
#        'ddf_scaled_down_v5.0.0_10yrs', 'four_roll_v5.0.0_10yrs',
#        'nes_all_v5.0.0_10yrs', 'nes_early_v5.0.0_10yrs',
#        'new_performance_v5.0.0_10yrs', 'retro_baseline_v2.0_10yrs',
#        'templates_all_v5.0.0_10yrs', 'tma_10_v5.0.0_10yrs',
#        'tma_20_v5.0.0_10yrs', 'twosnaps_v5.0.0_10yrs',
#        'weather_cloudso0v5.0.0_10yrs', 'weather_cloudso10v5.0.0_10yrs',
#        'weather_cloudso12v5.0.0_10yrs', 'weather_cloudso14v5.0.0_10yrs',
#        'weather_cloudso16v5.0.0_10yrs', 'weather_cloudso18v5.0.0_10yrs',
#        'weather_cloudso1v5.0.0_10yrs', 'weather_cloudso20v5.0.0_10yrs',
#        'weather_cloudso2v5.0.0_10yrs', 'weather_cloudso30v5.0.0_10yrs',
#        'weather_cloudso31v5.0.0_10yrs', 'weather_cloudso35v5.0.0_10yrs',
#        'weather_cloudso36v5.0.0_10yrs', 'weather_cloudso4v5.0.0_10yrs',
#        'weather_cloudso6v5.0.0_10yrs', 'weather_cloudso8v5.0.0_10yrs'],
#       dtype='object', name='run')

# %%
metric_subsets = maf.get_metric_subsets('metric_subsets.json')
msets = list(metric_subsets.groupby('metric subset').first().index)
# DDF specific metrics
[m for m in msets if 'DDF' in m]
# Out:
# ['AGN SF DDF',
#  'AGN TimeLag 100 days DDF',
#  'AGN TimeLag 5 days DDF',
#  'DDF Cadence',
#  'DDF Depths',
#  'SNIa DDF',
#  'SNSL DDF']

# %%
m5_SRD_design = {'u': 23.90, 'g': 25.00, 'r': 24.70, 'i': 24.00, 'z': 23.30, 'y': 22.10}
m5_SRD_minimum = {'u': 23.40, 'g':24.60, 'r': 24.30, 'i': 23.60, 'z': 22.90, 'y': 21.70}

# Weather variations on baseline strategy
weather_runs = [r for r in summaries.index if 'weather' in r]
offsets = [int(w.split('dso')[-1].split('v5')[0]) for w in weather_runs]
idx = np.argsort(offsets)
weather_runs = [weather_runs[i] for i in idx]
print("weather runs", len(weather_runs))

# Start date variations
start_dates = [r for r in summaries.index if 'start_date' in r]
offsets = [int(r.split('mjdp')[-1].split('_')[0]) for r in start_dates]
idx = np.argsort(offsets)
start_dates = [start_dates[i] for i in idx]
print("start_dates", len(start_dates))


# Baseline sims, and put them in order of evolution

baseline_dict = {'retro_baseline_v2.0_10yrs': 'v1.x', 
                 'baseline_v2.0_10yrs':'v2.0', 
                 'baseline_v2.1_10yrs':'v2.1',
                 'baseline_v2.2_10yrs':'v2.2',
                 'baseline_v3.0_10yrs':'v3.0',
                 'baseline_v3.2_10yrs':'v3.2',
                'baseline_v3.3_10yrs':'v3.3',
                'baseline_v3.4_10yrs': 'v3.4',
                'baseline_v3.5_10yrs': 'v3.5', 
                 'baseline_v3.6_10yrs': 'v3.6',
                 'baseline_v4.0_10yrs': 'v4.0',
                 'baseline_v4.3.5_10yrs': 'v4.3.5',
                }

newbaselines_dict = {'baseline_v5.0.0_10yrs': 'baseline v5.0.0', 
                     'four_roll_v5.0.0_10yrs': "four cycle v5.0.0",
                    'twosnaps_v5.0.0_10yrs' : "two snaps v5.0.0",                     
                    }

rdict = {}
for k in baseline_dict:
    rdict[k] = baseline_dict[k]
for k in newbaselines_dict:
    rdict[k] = newbaselines_dict[k]

runs = list(rdict.keys())
baseline = 'baseline_v5.0.0_10yrs'
baselinerun = baseline

ddf_accord = ['ddf_accourdion_v5.0.0_10yrs',]
ddf_scale = ['ddf_scaled_down_v5.0.0_10yrs',]
ddf_dither = [ 'ddf_dither_0.0_v5.0.0_10yrs',
                'ddf_dither_0.1_v5.0.0_10yrs',
             'ddf_dither_0.2_v5.0.0_10yrs',
             'ddf_dither_0.4_v5.0.0_10yrs',
             'ddf_dither_0.8_v5.0.0_10yrs',]


ddf_sets = [ ddf_accord, ddf_scale, ddf_dither]
ddf_runs = [r for r in ddf_accord] + [r for r in ddf_scale] + [r for r in ddf_dither]

outdir = 'tmp_fig'
try:
    os.mkdir(outdir)
except:
    pass
# Out:
# weather runs 16
# start_dates 0

# %% [markdown]
# ### Deep drilling field observing strategy
#
# The baseline run (baseline_v5.0.0) can be compared against the various modifications of the DDF strategy.
# The detailed MAF metrics for each simulation are available here - http://usdf-maf.slac.stanford.edu - with particular emphasis on the "DD metrics".

# %% [markdown]
# The baseline survey strategy for the DDFs includes 5 DDF pointings, with varying number of visits per DDF:
# * COSMOS attains 10 year DDF depth by year 3, and continues observations thus acquiring almost double the other pointings.
# * Euclid Deep Field South (EDFS) is split into two different pointings (a, b) to match the Euclid field size, but share the total number of visits.
# * A rough baseline number is that each DDF obtains about 21,000 visits over 10 years, corresponding to about 6% of the total (2.1M) visits.
#
# After v4.1, the maximum extent DDF dithers is about 0.2 degrees. We need to reconsider this at this time, as DM are worried about calibration and in particular, stray light.
#
# All of the DDF simulations use a variation on 'ocean' - a mix of deep and shallow sequences in different years.
#
# The "ddf_accord" adds an accordian strategy in the shallow seasons.

# %%
all_runs =  ['baseline_v5.0.0_10yrs',] + ddf_runs
all_runs
# Out:
# ['baseline_v5.0.0_10yrs',
#  'ddf_accourdion_v5.0.0_10yrs',
#  'ddf_scaled_down_v5.0.0_10yrs',
#  'ddf_dither_0.0_v5.0.0_10yrs',
#  'ddf_dither_0.1_v5.0.0_10yrs',
#  'ddf_dither_0.2_v5.0.0_10yrs',
#  'ddf_dither_0.4_v5.0.0_10yrs',
#  'ddf_dither_0.8_v5.0.0_10yrs']

# %%
# Basic DDF information, number of visits from baseline simulation
ddfs = ddf_locations(skycoords=True)
nvis = {}
for run in all_runs:
    conn = sqlite3.connect(run + ".db") 
    nvis[run] = {}
    for i in ddfs:
        query = f"select count(*) from observations where scheduler_note like '%{i}%'"
        nvis[run][i] = int(pd.read_sql(query, conn).values[0][0])

pdfs = {}
for i in ddfs:
    ra = ddfs[i].ra.deg
    dec = ddfs[i].dec.deg
    coord = ddfs[i]
    ra_hours = coord.ra.hms
    eclip_lat = coord.barycentrictrueecliptic.lat.deg
    eclip_lon = coord.barycentrictrueecliptic.lon.deg
    gal_lon = coord.galactic.l.deg
    gal_lat = coord.galactic.b.deg
    pdfs[i] = [ra, dec, gal_lon, gal_lat, eclip_lon, eclip_lat]
d = pd.DataFrame(pdfs, index=['RA', 'Dec', 'Gal l', 'Gal b', 'Eclip l', 'Eclip b']).round(2)
n = pd.DataFrame(nvis).T
d = pd.concat([d, n])
d
# Out:
#                                ELAISS1   XMM_LSS     ECDFS    COSMOS  \
# RA                                9.45     35.57     52.98    150.11
# Dec                             -44.02     -4.82    -28.12      2.23
# Gal l                           311.29    171.10    224.07    236.78
# Gal b                           -72.88    -58.91    -54.60     42.13
# Eclip l                         346.66     31.59     40.81    151.39
# Eclip b                         -43.20    -17.92    -45.44     -9.34
# baseline_v5.0.0_10yrs         19704.00  18910.00  20455.00  41707.00
# ddf_accourdion_v5.0.0_10yrs   21181.00  20194.00  21975.00  43507.00
# ddf_scaled_down_v5.0.0_10yrs  18582.00  17768.00  19484.00  38490.00
# ddf_dither_0.0_v5.0.0_10yrs   19744.00  18872.00  20483.00  41788.00
# ddf_dither_0.1_v5.0.0_10yrs   19737.00  18845.00  20520.00  41740.00
# ddf_dither_0.2_v5.0.0_10yrs   19704.00  18910.00  20455.00  41707.00
# ddf_dither_0.4_v5.0.0_10yrs   19779.00  18916.00  20436.00  41730.00
# ddf_dither_0.8_v5.0.0_10yrs   19716.00  18919.00  20503.00  41717.00
#
#                                 EDFS_a    EDFS_b
# RA                               58.90     63.60
# Dec                             -49.32    -47.60
# Gal l                           257.90    254.48
# Gal b                           -48.46    -45.77
# Eclip l                          32.00     40.97
# Eclip b                         -66.61    -66.60
# baseline_v5.0.0_10yrs         12434.00  12350.00
# ddf_accourdion_v5.0.0_10yrs   13494.00  13348.00
# ddf_scaled_down_v5.0.0_10yrs  12384.00  12283.00
# ddf_dither_0.0_v5.0.0_10yrs   12415.00  12345.00
# ddf_dither_0.1_v5.0.0_10yrs   12425.00  12343.00
# ddf_dither_0.2_v5.0.0_10yrs   12434.00  12350.00
# ddf_dither_0.4_v5.0.0_10yrs   12429.00  12342.00
# ddf_dither_0.8_v5.0.0_10yrs   12421.00  12335.00

# %% [markdown]
# ## Very high level "wfd" scoc metrics

# %%
# What about the SCOC high-level overview? 

msub = metric_subsets.loc['SCOC']

fig, ax = maf.plot_run_metric_mesh(summaries.loc[all_runs, msub['metric']], 
                     baseline_run=baseline,
                     metric_subset=msub,
                    metric_label_map=msub['short_name'],
                    color_range=0.2,
                      )
fig.set_figwidth(10)

# %% [markdown]
# ## Fraction of DDF time
#
# Varying the DDF strategy can inadvertently change the overall number of DDF visits or the overall fraction of survey time devoted to DDF observations. Changes here can affect the overall metrics for the strategy, so is worth checking first to identify which runs could be considered the most "apples to apples".

# %%
visits = ['Identity Nvisits All visits UniSlicer', 'Identity Nvisits DDF UniSlicer']
fraction = pd.DataFrame(summaries.loc[all_runs, visits[1]] / summaries.loc[all_runs, visits[0]],
                       columns=["Fraction of DDF visits per run"])

fig, ax = maf.plot_run_metric(fraction, shade_fraction=None,
                              vertical_quantity='value', horizontal_quantity='run')
plt.legend(loc=(1.01, 0.2))
ax.axhline(fraction.loc[baselinerun].values, color='red', linestyle=':')
ylim = ax.set_ylim()
xi = 1.6
for q in ddf_sets:
    xii = len(q) + xi
    ax.fill_betweenx(np.arange(ylim[0], ylim[1], (ylim[1]-ylim[0])/100), xi, xii, alpha=0.3)
    xi = xii

# %% [markdown]
# The plot of fraction of DDF visits in each simulation shows that most of the simulations vary slightly around the 6% achieved in the baseline simulation.
#
# We can also double check on the end of survey coadded depths for each DDF in each filter -- in general, we'd expect them to track with fraction of time, but also amount of dithering.

# %%
msub = metric_subsets.loc['DDF Depths'].query("not metric.str.contains('WFD') and metric.str.contains('Coadd')")
fig, ax = maf.plot_run_metric(summaries.loc[all_runs, msub['metric']], 
                              baseline_run=baselinerun,
                              metric_subset=msub,
                              metric_label_map=msub['short_name'],
                              linestyles='-',
                              shade_fraction=None,
                              vertical_quantity='value', horizontal_quantity='run')
plt.legend(loc=(1.01, -0.3))
ylim = ax.set_ylim()
xi = 1.6
for q in ddf_sets:
    xii = len(q) + xi
    ax.fill_betweenx(np.arange(ylim[0], ylim[1], (ylim[1]-ylim[0])/100), xi, xii, alpha=0.3)
    xi = xii

# %%
for i in ddfs:
    if i == 'EDFS_a':
        name = 'EDFS'
    elif i == "EDFS_b":
        continue
    else:
        name = i
    msub = metric_subsets.loc['DDF Depths'].query("metric.str.contains(@name) and metric.str.contains('Coadd')")
    print(name)
    display(summaries.loc[all_runs, msub['metric']].round(2).rename(columns=msub['short_name']))
# Out:
# ELAISS1
# metric                        CoaddedM5 ELAISS1 u  CoaddedM5 ELAISS1 g  \
# run
# baseline_v5.0.0_10yrs                       27.52                28.52
# ddf_accourdion_v5.0.0_10yrs                 27.59                28.47
# ddf_scaled_down_v5.0.0_10yrs                27.52                28.51
# ddf_dither_0.0_v5.0.0_10yrs                 27.52                28.51
# ddf_dither_0.1_v5.0.0_10yrs                 27.53                28.53
# ddf_dither_0.2_v5.0.0_10yrs                 27.52                28.52
# ddf_dither_0.4_v5.0.0_10yrs                 27.48                28.47
# ddf_dither_0.8_v5.0.0_10yrs                 27.35                28.34
#
# metric                        CoaddedM5 ELAISS1 r  CoaddedM5 ELAISS1 i  \
# run
# baseline_v5.0.0_10yrs                       28.48                28.49
# ddf_accourdion_v5.0.0_10yrs                 28.52                28.48
# ddf_scaled_down_v5.0.0_10yrs                28.47                28.47
# ddf_dither_0.0_v5.0.0_10yrs                 28.47                28.49
# ddf_dither_0.1_v5.0.0_10yrs                 28.48                28.50
# ddf_dither_0.2_v5.0.0_10yrs                 28.48                28.49
# ddf_dither_0.4_v5.0.0_10yrs                 28.43                28.45
# ddf_dither_0.8_v5.0.0_10yrs                 28.30                28.32
#
# metric                        CoaddedM5 ELAISS1 z  CoaddedM5 ELAISS1 y
# run
# baseline_v5.0.0_10yrs                       27.84                25.99
# ddf_accourdion_v5.0.0_10yrs                 27.87                26.14
# ddf_scaled_down_v5.0.0_10yrs                27.83                25.99
# ddf_dither_0.0_v5.0.0_10yrs                 27.83                25.98
# ddf_dither_0.1_v5.0.0_10yrs                 27.85                26.00
# ddf_dither_0.2_v5.0.0_10yrs                 27.84                25.99
# ddf_dither_0.4_v5.0.0_10yrs                 27.80                25.95
# ddf_dither_0.8_v5.0.0_10yrs                 27.67                25.84
# XMM_LSS
# metric                        CoaddedM5 XMM_LSS u  CoaddedM5 XMM_LSS g  \
# run
# baseline_v5.0.0_10yrs                       27.42                28.39
# ddf_accourdion_v5.0.0_10yrs                 27.50                28.34
# ddf_scaled_down_v5.0.0_10yrs                27.42                28.39
# ddf_dither_0.0_v5.0.0_10yrs                 27.41                28.39
# ddf_dither_0.1_v5.0.0_10yrs                 27.43                28.39
# ddf_dither_0.2_v5.0.0_10yrs                 27.42                28.39
# ddf_dither_0.4_v5.0.0_10yrs                 27.38                28.35
# ddf_dither_0.8_v5.0.0_10yrs                 27.24                28.23
#
# metric                        CoaddedM5 XMM_LSS r  CoaddedM5 XMM_LSS i  \
# run
# baseline_v5.0.0_10yrs                       28.34                28.37
# ddf_accourdion_v5.0.0_10yrs                 28.38                28.35
# ddf_scaled_down_v5.0.0_10yrs                28.33                28.33
# ddf_dither_0.0_v5.0.0_10yrs                 28.33                28.35
# ddf_dither_0.1_v5.0.0_10yrs                 28.34                28.36
# ddf_dither_0.2_v5.0.0_10yrs                 28.34                28.37
# ddf_dither_0.4_v5.0.0_10yrs                 28.31                28.32
# ddf_dither_0.8_v5.0.0_10yrs                 28.18                28.19
#
# metric                        CoaddedM5 XMM_LSS z  CoaddedM5 XMM_LSS y
# run
# baseline_v5.0.0_10yrs                       27.68                25.91
# ddf_accourdion_v5.0.0_10yrs                 27.69                26.08
# ddf_scaled_down_v5.0.0_10yrs                27.65                25.92
# ddf_dither_0.0_v5.0.0_10yrs                 27.67                25.91
# ddf_dither_0.1_v5.0.0_10yrs                 27.67                25.91
# ddf_dither_0.2_v5.0.0_10yrs                 27.68                25.91
# ddf_dither_0.4_v5.0.0_10yrs                 27.64                25.88
# ddf_dither_0.8_v5.0.0_10yrs                 27.49                25.75
# ECDFS
# metric                        CoaddedM5 ECDFS u  CoaddedM5 ECDFS g  \
# run
# baseline_v5.0.0_10yrs                     27.60              28.57
# ddf_accourdion_v5.0.0_10yrs               27.68              28.53
# ddf_scaled_down_v5.0.0_10yrs              27.60              28.56
# ddf_dither_0.0_v5.0.0_10yrs               27.59              28.56
# ddf_dither_0.1_v5.0.0_10yrs               27.60              28.57
# ddf_dither_0.2_v5.0.0_10yrs               27.60              28.57
# ddf_dither_0.4_v5.0.0_10yrs               27.55              28.52
# ddf_dither_0.8_v5.0.0_10yrs               27.43              28.40
#
# metric                        CoaddedM5 ECDFS r  CoaddedM5 ECDFS i  \
# run
# baseline_v5.0.0_10yrs                     28.48              28.50
# ddf_accourdion_v5.0.0_10yrs               28.54              28.49
# ddf_scaled_down_v5.0.0_10yrs              28.48              28.50
# ddf_dither_0.0_v5.0.0_10yrs               28.48              28.50
# ddf_dither_0.1_v5.0.0_10yrs               28.49              28.51
# ddf_dither_0.2_v5.0.0_10yrs               28.48              28.50
# ddf_dither_0.4_v5.0.0_10yrs               28.43              28.46
# ddf_dither_0.8_v5.0.0_10yrs               28.31              28.33
#
# metric                        CoaddedM5 ECDFS z  CoaddedM5 ECDFS y
# run
# baseline_v5.0.0_10yrs                     27.83              26.07
# ddf_accourdion_v5.0.0_10yrs               27.85              26.19
# ddf_scaled_down_v5.0.0_10yrs              27.82              26.07
# ddf_dither_0.0_v5.0.0_10yrs               27.83              26.07
# ddf_dither_0.1_v5.0.0_10yrs               27.84              26.07
# ddf_dither_0.2_v5.0.0_10yrs               27.83              26.07
# ddf_dither_0.4_v5.0.0_10yrs               27.78              26.03
# ddf_dither_0.8_v5.0.0_10yrs               27.65              25.89
# COSMOS
# metric                        CoaddedM5 COSMOS u  CoaddedM5 COSMOS g  \
# run
# baseline_v5.0.0_10yrs                      27.22               28.53
# ddf_accourdion_v5.0.0_10yrs                27.32               28.55
# ddf_scaled_down_v5.0.0_10yrs               27.21               28.52
# ddf_dither_0.0_v5.0.0_10yrs                27.21               28.54
# ddf_dither_0.1_v5.0.0_10yrs                27.21               28.54
# ddf_dither_0.2_v5.0.0_10yrs                27.22               28.53
# ddf_dither_0.4_v5.0.0_10yrs                27.17               28.50
# ddf_dither_0.8_v5.0.0_10yrs                27.06               28.38
#
# metric                        CoaddedM5 COSMOS r  CoaddedM5 COSMOS i  \
# run
# baseline_v5.0.0_10yrs                      28.76               28.96
# ddf_accourdion_v5.0.0_10yrs                28.81               28.97
# ddf_scaled_down_v5.0.0_10yrs               28.75               28.93
# ddf_dither_0.0_v5.0.0_10yrs                28.77               28.96
# ddf_dither_0.1_v5.0.0_10yrs                28.77               28.97
# ddf_dither_0.2_v5.0.0_10yrs                28.76               28.96
# ddf_dither_0.4_v5.0.0_10yrs                28.73               28.91
# ddf_dither_0.8_v5.0.0_10yrs                28.59               28.78
#
# metric                        CoaddedM5 COSMOS z  CoaddedM5 COSMOS y
# run
# baseline_v5.0.0_10yrs                      28.25               25.70
# ddf_accourdion_v5.0.0_10yrs                28.28               25.88
# ddf_scaled_down_v5.0.0_10yrs               28.23               25.70
# ddf_dither_0.0_v5.0.0_10yrs                28.25               25.70
# ddf_dither_0.1_v5.0.0_10yrs                28.26               25.70
# ddf_dither_0.2_v5.0.0_10yrs                28.25               25.70
# ddf_dither_0.4_v5.0.0_10yrs                28.22               25.66
# ddf_dither_0.8_v5.0.0_10yrs                28.08               25.57
# EDFS
# metric                        CoaddedM5 EDFS u  CoaddedM5 EDFS g  \
# run
# baseline_v5.0.0_10yrs                    27.34             28.28
# ddf_accourdion_v5.0.0_10yrs              27.27             28.24
# ddf_scaled_down_v5.0.0_10yrs             27.35             28.28
# ddf_dither_0.0_v5.0.0_10yrs              27.33             28.28
# ddf_dither_0.1_v5.0.0_10yrs              27.34             28.28
# ddf_dither_0.2_v5.0.0_10yrs              27.34             28.28
# ddf_dither_0.4_v5.0.0_10yrs              27.34             28.28
# ddf_dither_0.8_v5.0.0_10yrs              27.34             28.28
#
# metric                        CoaddedM5 EDFS r  CoaddedM5 EDFS i  \
# run
# baseline_v5.0.0_10yrs                    28.27             28.35
# ddf_accourdion_v5.0.0_10yrs              28.37             28.34
# ddf_scaled_down_v5.0.0_10yrs             28.27             28.35
# ddf_dither_0.0_v5.0.0_10yrs              28.26             28.35
# ddf_dither_0.1_v5.0.0_10yrs              28.27             28.35
# ddf_dither_0.2_v5.0.0_10yrs              28.27             28.35
# ddf_dither_0.4_v5.0.0_10yrs              28.27             28.35
# ddf_dither_0.8_v5.0.0_10yrs              28.27             28.35
#
# metric                        CoaddedM5 EDFS z  CoaddedM5 EDFS y
# run
# baseline_v5.0.0_10yrs                    27.62             25.69
# ddf_accourdion_v5.0.0_10yrs              27.67             25.93
# ddf_scaled_down_v5.0.0_10yrs             27.62             25.70
# ddf_dither_0.0_v5.0.0_10yrs              27.62             25.70
# ddf_dither_0.1_v5.0.0_10yrs              27.62             25.71
# ddf_dither_0.2_v5.0.0_10yrs              27.62             25.69
# ddf_dither_0.4_v5.0.0_10yrs              27.62             25.70
# ddf_dither_0.8_v5.0.0_10yrs              27.62             25.70

# %%
# Median season length (across all seasons)
msub = metric_subsets.loc['DDF Cadence'].query('metric.str.contains("Season Length") and not metric.str.contains("WFD")')
fig, ax = maf.plot_run_metric(summaries.loc[all_runs, msub['metric']], 
                              #metric_subset=msub,
                              metric_label_map=msub['short_name'],
                              linestyles='-',
                              shade_fraction=None,
                              vertical_quantity='value', horizontal_quantity='run')
plt.legend(loc=(1.01, 0.2))
ylim = ax.set_ylim()
xi = 1.6
for q in ddf_sets:
    xii = len(q) + xi
    ax.fill_betweenx(np.arange(ylim[0], ylim[1], (ylim[1]-ylim[0])/100), xi, xii, alpha=0.3)
    xi = xii

# %%
# Median inter-night gap in r band; i and z band similar trends
msub = metric_subsets.loc['DDF Cadence'].query('metric.str.contains("Gap r") and not metric.str.contains("WFD")')
fig, ax = maf.plot_run_metric(summaries.loc[all_runs, msub['metric']], 
                              #metric_subset=msub,
                              metric_label_map=msub['short_name'],
                              linestyles='-',
                              shade_fraction=None,
                              vertical_quantity='value', horizontal_quantity='run')
plt.legend(loc=(1.01, 0.2))
ylim = ax.set_ylim()
xi = 1.6
for q in ddf_sets:
    xii = len(q) + xi
    ax.fill_betweenx(np.arange(ylim[0], ylim[1], (ylim[1]-ylim[0])/100), xi, xii, alpha=0.3)
    xi = xii

# %%
msub = metric_subsets.loc['DDF Cadence'].query('metric.str.contains("Gap g") and not metric.str.contains("WFD")')
fig, ax = maf.plot_run_metric(summaries.loc[all_runs, msub['metric']], 
                              #metric_subset=msub,
                              metric_label_map=msub['short_name'],
                              linestyles='-',
                              shade_fraction=None,
                              vertical_quantity='value', horizontal_quantity='run')
plt.legend(loc=(1.01, 0.2))
ylim = ax.set_ylim()
xi = 1.6
for q in ddf_sets:
    xii = len(q) + xi
    ax.fill_betweenx(np.arange(ylim[0], ylim[1], (ylim[1]-ylim[0])/100), xi, xii, alpha=0.3)
    xi = xii

# %%
metric = [m for m in summaries if 'DD:' in m and 'Median Inter-Night Gap all bands' in m and 'WFD' not in m]
short_names = [f"Median Inter-Night Gap (any) {m.split('DD:')[1].split(' ')[0]}" for m in metric]
mapper = dict(zip(metric, short_names))
fig, ax = maf.plot_run_metric(summaries.loc[all_runs, metric],
                              #metric_subset=msub,
                              metric_label_map=mapper,
                              linestyles='-',
                              shade_fraction=None,
                              vertical_quantity='value', horizontal_quantity='run')
plt.legend(loc=(1.01, 0.2))
ylim = ax.set_ylim()
xi = 1.6
for q in ddf_sets:
    xii = len(q) + xi
    ax.fill_betweenx(np.arange(ylim[0], ylim[1], (ylim[1]-ylim[0])/100), xi, xii, alpha=0.3)
    xi = xii

# %% [markdown]
#  (It's worthwhile to note that these metrics are calculated based on gaps in *any* location in the DDF, because they are just evaluating the gaps between nights with DDF visits in that field .. the slicer is a "UniSlicer", not a "HealpixSubsetSlicer" which would consider which ra/dec value in particular is being observed .. the dither size should impact metrics evaluated with the HealpixSubsetSlicer but not the UniSlicer.).

# %%
# Viewing this in a different way 
msub = metric_subsets.loc['DDF Cadence']
ddfs = ['COSMOS', 'XMM_LSS', 'ELAISS1', 'ECDFS', 'EDFS']
                                                         
fig = plt.figure(figsize=(15, 15))
gs = fig.add_gridspec(ncols=5, nrows=1, wspace=0.1)
axs = gs.subplots(sharey=True)
for dd, ax  in zip(ddfs, axs):
    msubset = msub.query('metric.str.contains(@dd)')
    fig, ax = maf.plot_run_metric(summaries.loc[all_runs, msubset['metric']],
                                  baseline_run=baselinerun,
                                  metric_label_map=msubset['short_name'],
                                  metric_subset=msubset,
                                 horizontal_quantity='value',
                                 vertical_quantity='run',
                                 ax=ax)
    ax.get_legend().remove()
    ax.set_xlim(0.2, 3)
    ax.set_title(dd)
ax.legend(loc=(1.01, 0.5))

# %%
msub = metric_subsets.loc['DDF Depths']
ddfs = ['COSMOS', 'XMM_LSS', 'ELAISS1', 'ECDFS', 'EDFS']
                                                         
fig = plt.figure(figsize=(15, 15))
gs = fig.add_gridspec(ncols=5, nrows=1, wspace=0.1)
axs = gs.subplots(sharey=True)
for dd, ax  in zip(ddfs, axs):
    msubset = msub.query('metric.str.contains(@dd)')
    fig, ax = maf.plot_run_metric(summaries.loc[all_runs, msubset['metric']],
                                  baseline_run=baselinerun,
                                  metric_label_map=msubset['short_name'],
                                  metric_subset=msubset,
                                 horizontal_quantity='value',
                                 vertical_quantity='run',
                                 ax=ax)
    ax.get_legend().remove()
    #ax.set_xlim(0.2, 1.5)
    ax.set_title(dd)
ax.legend(loc=(1.01, 0.5))

# %% [markdown]
# With some insights into what's happening in the DDFs with these variations in survey strategy, let's look at the metrics more oriented toward science and see how they respond.

# %% [markdown]
# ## AGN metrics

# %%
msub = metric_subsets.loc['AGN SF DDF'].query('not metric.str.contains("WFD")')
u = msub.iloc[::6]
g = msub.iloc[1::6]
r = msub.iloc[2::6]
ddf_names = [i.split("DD:")[1].split(' ')[0] for i in r['metric']]
agn_sf = pd.DataFrame(summaries.loc[all_runs, u['metric']].values * 2 
                      + summaries.loc[all_runs, g['metric']].values * 1 
                      + summaries.loc[all_runs, r['metric']].values * 1,
                      columns=ddf_names, index=all_runs)
fig, ax = maf.plot_run_metric(agn_sf, shade_fraction=None,
                            vertical_quantity='value', horizontal_quantity='run')
ylim = ax.set_ylim()
xi = 1.6
for q in ddf_sets:
    xii = len(q) + xi
    ax.fill_betweenx(np.arange(ylim[0], ylim[1], (ylim[1]-ylim[0])/100), xi, xii, alpha=0.3)
    xi = xii
ax.set_ylim(ylim[1], ylim[0])
plt.title("AGN SF Error combined (2*u+g+r)")
# Out:
# Text(0.5, 1.0, 'AGN SF Error combined (2*u+g+r)')

# %%
msub = metric_subsets.loc['AGN SF DDF']
ddfs = ['COSMOS', 'XMM_LSS', 'ELAISS1', 'ECDFS', 'EDFS']
                                                         
fig = plt.figure(figsize=(15, 15))
gs = fig.add_gridspec(ncols=5, nrows=1, wspace=0.1)
axs = gs.subplots(sharey=True)
for dd, ax  in zip(ddfs, axs):
    msubset = msub.query('metric.str.contains(@dd)')
    fig, ax = maf.plot_run_metric(summaries.loc[all_runs, msubset['metric']],
                                  baseline_run=baselinerun,
                                  metric_label_map=msubset['short_name'],
                                  metric_subset=msubset,
                                 horizontal_quantity='value',
                                 vertical_quantity='run',
                                 ax=ax)
    ax.get_legend().remove()
    #ax.set_xlim(0.2, 1.5)
    ax.set_title(dd)
ax.legend(loc=(1.01, 0.5))

# %%
msub = metric_subsets.loc['AGN TimeLag 100 days DDF'].query('not metric.str.contains("WFD") and not metric.str.contains("all bands")')
u = msub.iloc[::6]
g = msub.iloc[1::6]
r = msub.iloc[2::6]
ddf_names = [i.split("DD:")[1].split(' ')[0] for i in r['metric']]
values = pd.DataFrame(summaries.loc[all_runs, u['metric']].values * 2 
                      + summaries.loc[all_runs, g['metric']].values * 1 
                      + summaries.loc[all_runs, r['metric']].values * 1,
                      columns=ddf_names, index=all_runs)
fig, ax = maf.plot_run_metric(values, shade_fraction=None,
                            vertical_quantity='value', horizontal_quantity='run')
ylim = ax.set_ylim()
xi = 1.6
for q in ddf_sets:
    xii = len(q) + xi
    ax.fill_betweenx(np.arange(ylim[0], ylim[1], (ylim[1]-ylim[0])/100), xi, xii, alpha=0.3)
    xi = xii
plt.title("AGN Timelags 100 days combined (2*u+g+r)")
# Out:
# Text(0.5, 1.0, 'AGN Timelags 100 days combined (2*u+g+r)')

# %%
msub = metric_subsets.loc['AGN TimeLag 5 days DDF'].query('not metric.str.contains("WFD") and metric.str.contains("all bands")')

ddf_names = [i.split("DD:")[1].split(' ')[0] for i in msub['metric']]
values = pd.DataFrame(summaries.loc[all_runs, msub['metric']].values,
                      columns=ddf_names, index=all_runs)
fig, ax = maf.plot_run_metric(values, shade_fraction=None,
                            vertical_quantity='value', horizontal_quantity='run')
ylim = ax.set_ylim()
xi = 1.6
for q in ddf_sets:
    xii = len(q) + xi
    ax.fill_betweenx(np.arange(ylim[0], ylim[1], (ylim[1]-ylim[0])/100), xi, xii, alpha=0.3)
    xi = xii
plt.title("AGN Timelags 5 days all bands")
# Out:
# Text(0.5, 1.0, 'AGN Timelags 5 days all bands')

# %% [markdown]
# ### SNIa metrics
#
# The SNIa metrics run here with an nside of 128, which is significantly higher resolution than we use for evaluating the main survey.

# %%
msub = metric_subsets.loc['SNIa DDF'].query('not metric.str.contains("WFD") and \
                                           metric.str.contains("Sum")')
fig, ax = maf.plot_run_metric(summaries.loc[all_runs, msub['metric']], 
                              #metric_subset=msub,
                              metric_label_map=msub['short_name'],
                              linestyles='-',
                              shade_fraction=None,
                              vertical_quantity='value', horizontal_quantity='run')
plt.legend(loc=(1.01, 0.2))
ylim = ax.set_ylim()
xi = 1.6
for q in ddf_sets:
    xii = len(q) + xi
    ax.fill_betweenx(np.arange(ylim[0], ylim[1], (ylim[1]-ylim[0])/100), xi, xii, alpha=0.3)
    xi = xii

# %%
msub = metric_subsets.loc['SNIa DDF'].query('not metric.str.contains("WFD") and \
                                           metric.str.contains("zlim")')
fig, ax = maf.plot_run_metric(summaries.loc[all_runs, msub['metric']], 
                              #metric_subset=msub,
                              metric_label_map=msub['short_name'],
                              linestyles='-',
                              shade_fraction=None,
                              vertical_quantity='value', horizontal_quantity='run')
plt.legend(loc=(1.01, 0.2))
ylim = ax.set_ylim()
xi = 1.6
for q in ddf_sets:
    xii = len(q) + xi
    ax.fill_betweenx(np.arange(ylim[0], ylim[1], (ylim[1]-ylim[0])/100), xi, xii, alpha=0.3)
    xi = xii

# %%
msub1 = metric_subsets.loc['SNIa DDF'].query('not metric.str.contains("WFD") and \
                                           metric.str.contains("Sum")')
msub2 = metric_subsets.loc['SNIa DDF'].query('not metric.str.contains("WFD") and \
                                           metric.str.contains("zlim")')
total_sn = summaries.loc[all_runs + weather_runs + list(baseline_dict.keys()), msub1['metric']].sum(axis=1)
median_zlim = summaries.loc[all_runs + weather_runs + list(baseline_dict.keys()), msub2['metric']].median(axis=1)

for fam, label in zip([weather_runs, ddf_accord, ddf_dither, ['baseline_v5.0.0_10yrs'], ['baseline_v4.3.5_10yrs',]], ['weather', 'accord', 'dither', 'v5.0', 'v4.3']):
    plt.plot(total_sn.loc[fam], median_zlim.loc[fam], marker='.', linestyle='', label=label)
plt.xlabel("Total SNIa")
plt.ylabel("Median zlim")
plt.legend(loc=(1.01, 0.2))
plt.grid(alpha=0.3)

# %% [markdown]
# #### SNIa summary
#
# No results yet.

# %%
msub = metric_subsets.loc['DDF Cadence'].query('not metric.str.contains("WFD") and \
                                           metric.str.contains("N Unique")')
fig, ax = maf.plot_run_metric(summaries.loc[all_runs, msub['metric']], 
                              baseline_run=baselinerun,
                              #metric_subset=msub,
                              metric_label_map=msub['short_name'],
                              linestyles='-',
                              shade_fraction=None,
                              vertical_quantity='value', horizontal_quantity='run')
plt.legend(loc=(1.01, 0.2))
ylim = ax.set_ylim()
xi = 1.6
for q in ddf_sets:
    xii = len(q) + xi
    ax.fill_betweenx(np.arange(ylim[0], ylim[1], (ylim[1]-ylim[0])/100), xi, xii, alpha=0.3)
    xi = xii

# %% [markdown]
# This metric DOES include the dither effects, as it's evaluated on a HealpixSubsetSlicer basis.

# %% [markdown]
# ## SLSN
#
# Strongly lensed SN

# %%
msub = metric_subsets.loc['SNSL DDF'].query('not metric.str.contains("WFD")')
fig, ax = maf.plot_run_metric(summaries.loc[all_runs, msub['metric']], 
                              baseline_run=baselinerun,
                              #metric_subset=msub,
                              metric_label_map=msub['short_name'],
                              linestyles='-',
                              shade_fraction=None,
                              vertical_quantity='value', horizontal_quantity='run')
plt.legend(loc=(1.01, 0.2))
ylim = ax.set_ylim()
xi = 1.6
for q in ddf_sets:
    xii = len(q) + xi
    ax.fill_betweenx(np.arange(ylim[0], ylim[1], (ylim[1]-ylim[0])/100), xi, xii, alpha=0.3)
    xi = xii

# %%
summaries.loc[all_runs, msub['metric']]
# Out:
# metric                        Sum SNSLMetric DD:ELAISS1 all bands HealpixSubsetSlicer  \
# run
# baseline_v5.0.0_10yrs                                                  0.022694
# ddf_accourdion_v5.0.0_10yrs                                            0.025760
# ddf_scaled_down_v5.0.0_10yrs                                           0.022560
# ddf_dither_0.0_v5.0.0_10yrs                                            0.022734
# ddf_dither_0.1_v5.0.0_10yrs                                            0.023013
# ddf_dither_0.2_v5.0.0_10yrs                                            0.022694
# ddf_dither_0.4_v5.0.0_10yrs                                            0.023107
# ddf_dither_0.8_v5.0.0_10yrs                                            0.022426
#
# metric                        Sum SNSLMetric DD:XMM_LSS all bands HealpixSubsetSlicer  \
# run
# baseline_v5.0.0_10yrs                                                  0.022568
# ddf_accourdion_v5.0.0_10yrs                                            0.024046
# ddf_scaled_down_v5.0.0_10yrs                                           0.022824
# ddf_dither_0.0_v5.0.0_10yrs                                            0.022483
# ddf_dither_0.1_v5.0.0_10yrs                                            0.022138
# ddf_dither_0.2_v5.0.0_10yrs                                            0.022568
# ddf_dither_0.4_v5.0.0_10yrs                                            0.022578
# ddf_dither_0.8_v5.0.0_10yrs                                            0.021855
#
# metric                        Sum SNSLMetric DD:COSMOS all bands HealpixSubsetSlicer  \
# run
# baseline_v5.0.0_10yrs                                                  0.020759
# ddf_accourdion_v5.0.0_10yrs                                            0.021482
# ddf_scaled_down_v5.0.0_10yrs                                           0.020655
# ddf_dither_0.0_v5.0.0_10yrs                                            0.020694
# ddf_dither_0.1_v5.0.0_10yrs                                            0.020851
# ddf_dither_0.2_v5.0.0_10yrs                                            0.020759
# ddf_dither_0.4_v5.0.0_10yrs                                            0.020966
# ddf_dither_0.8_v5.0.0_10yrs                                            0.020461
#
# metric                        Sum SNSLMetric DD:ECDFS all bands HealpixSubsetSlicer  \
# run
# baseline_v5.0.0_10yrs                                                  0.021631
# ddf_accourdion_v5.0.0_10yrs                                            0.025110
# ddf_scaled_down_v5.0.0_10yrs                                           0.021583
# ddf_dither_0.0_v5.0.0_10yrs                                            0.021376
# ddf_dither_0.1_v5.0.0_10yrs                                            0.021917
# ddf_dither_0.2_v5.0.0_10yrs                                            0.021631
# ddf_dither_0.4_v5.0.0_10yrs                                            0.021929
# ddf_dither_0.8_v5.0.0_10yrs                                            0.021537
#
# metric                        Sum SNSLMetric DD:EDFS all bands HealpixSubsetSlicer
# run
# baseline_v5.0.0_10yrs                                                  0.042239
# ddf_accourdion_v5.0.0_10yrs                                            0.050948
# ddf_scaled_down_v5.0.0_10yrs                                           0.041952
# ddf_dither_0.0_v5.0.0_10yrs                                            0.042156
# ddf_dither_0.1_v5.0.0_10yrs                                            0.042184
# ddf_dither_0.2_v5.0.0_10yrs                                            0.042239
# ddf_dither_0.4_v5.0.0_10yrs                                            0.042199
# ddf_dither_0.8_v5.0.0_10yrs                                            0.042101

# %% [markdown]
# ## KNe metrics

# %%
metrics = [m for m in summaries if 'KNe' in m and 'ztfrest_simple ' in m 
           and 'DD' in m and "Fraction detected in footprint" in m and 'WFD' not in m]
short_names = [f"KNe (TVS) {m.split('DD:')[1].split(' ')[0]}" for m in metrics]
mapper = dict(zip(metrics, short_names))
fig, ax = maf.plot_run_metric(summaries.loc[all_runs, metrics], 
                              linestyles='-',
                              metric_label_map=mapper,
                              shade_fraction=None,
                              vertical_quantity='value', horizontal_quantity='run')
plt.legend(loc=(1.01, 0.2))
ylim = ax.set_ylim()
xi = 1.6
for q in ddf_sets:
    xii = len(q) + xi
    ax.fill_betweenx(np.arange(ylim[0], ylim[1], (ylim[1]-ylim[0])/100), xi, xii, alpha=0.3)
    xi = xii

# %%
metrics = [m for m in summaries if 'KNe' in m  and 'multi_color_detect' in m 
           and 'DD' in m and "Fraction detected in footprint" in m and 'WFD' not in m]
short_names = [f"KNe (DESC) {m.split('DD:')[1].split(' ')[0]}" for m in metrics]
mapper = dict(zip(metrics, short_names))
fig, ax = maf.plot_run_metric(summaries.loc[all_runs, metrics], 
                              linestyles='-',
                              metric_label_map=mapper,
                              shade_fraction=None,
                              vertical_quantity='value', horizontal_quantity='run')
plt.legend(loc=(1.01, 0.2))
ylim = ax.set_ylim()
xi = 1.6
for q in ddf_sets:
    xii = len(q) + xi
    ax.fill_betweenx(np.arange(ylim[0], ylim[1], (ylim[1]-ylim[0])/100), xi, xii, alpha=0.3)
    xi = xii

# %% [markdown]
# ### Weak Lensing nvisits
#
# The weak lensing metric counts exposure time in gri or riz bands.

# %%
metrics = [m for m in summaries if "Weak" in m and "DD:" in m and "Median" in m and 'WFD' not in m and 'gri' in m]
short_names = [f"gri time {m.split('DD:')[1].split(' ')[0]}" for m in metrics]
mapper = dict(zip(metrics, short_names))
fig, ax = maf.plot_run_metric(summaries.loc[all_runs, metrics], 
                              linestyles='-',
                              metric_label_map=mapper,
                              shade_fraction=None,
                              vertical_quantity='value', horizontal_quantity='run')
plt.legend(loc=(1.01, 0.2))
ylim = ax.set_ylim()
xi = 1.6
for q in ddf_sets:
    xii = len(q) + xi
    ax.fill_betweenx(np.arange(ylim[0], ylim[1], (ylim[1]-ylim[0])/100), xi, xii, alpha=0.3)
    xi = xii

# %%
metrics = [m for m in summaries if "Weak" in m and "DD:" in m and "Median" in m and 'WFD' not in m and 'riz' in m]
short_names = [f"riz time {m.split('DD:')[1].split(' ')[0]}" for m in metrics]
mapper = dict(zip(metrics, short_names))
fig, ax = maf.plot_run_metric(summaries.loc[all_runs, metrics], 
                              linestyles='-',
                              metric_label_map=mapper,
                              shade_fraction=None,
                              vertical_quantity='value', horizontal_quantity='run')
plt.legend(loc=(1.01, 0.2))
ylim = ax.set_ylim()
xi = 1.6
for q in ddf_sets:
    xii = len(q) + xi
    ax.fill_betweenx(np.arange(ylim[0], ylim[1], (ylim[1]-ylim[0])/100), xi, xii, alpha=0.3)
    xi = xii
